# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
{Calcination Analysis - Notebook 1
Predictive modeling of reactivity based on geochemical and geomechanical data.}

{INTERNAL USE ONLY}
"""

from sklearn.feature_selection import f_regression
from pycaret.regression import setup, evaluate_model, compare_models, tune_model, dashboard
import seaborn as sns
import numpy as np
import pandas as pd
__author__ = '{Malte Schade}'
__copyright__ = 'Copyright {2022}, {Calcination Analysis - Notebook 1}'
__version__ = '{1}.{0}.{0}'
__maintainer__ = '{Malte Schade}'
__email__ = '{contact@malteschade.com}'
__status__ = '{PROTOTYPE}'

# built-in modules
import os
import collections.abc
collections.Iterable = collections.abc.Iterable
collections.Mapping = collections.abc.Mapping
collections.MutableSet = collections.abc.MutableSet
collections.MutableMapping = collections.abc.MutableMapping

# parameters
META_PATH = 'data/cleaned.csv'

# settings
pd.options.display.max_columns = None
sns.set(rc={'figure.figsize': (16, 9)})

# %%
# reading of raw datasets
df_calc = pd.read_csv(os.path.dirname(os.getcwd(
))+'/data/Conso/calcinationdata.csv', encoding="latin_1", index_col=False)
df_chem = pd.read_csv(os.path.dirname(os.getcwd()) +
                      '/data/Conso/chemdata.csv', encoding="latin_1")
df_dense = pd.read_csv(
    '/home/lhoist/code/calcination/data/Conso/Densitydata.csv', encoding='latin1')

# definition of regular expression patterns
rep_nan = '^$'
rep_none = '\'|¢XC|°C|N.A|-|¢X|#REF!|c|\+|SAL|\d+/\d+|ND|/|t|\*|\d+°\:'
rep_dot = ','


def replace(x: object) -> object:
    '''
    Function to replace patterns in data with correct formatting,
    clean data and do type casting.

    Parameters
    ----------
    x: object
        Dataframe string field value.

    Returns
    ----------
    x/y: object
        Either original object or transformed object as float.
    '''
    if x.dtype == object:
        y = x.str.replace(rep_dot, '.', regex=True)
        y = y.str.replace(rep_none, '', regex=True)
        y = y.str.replace('..', '.', regex=False)
        y = y.replace(rep_nan, np.nan, regex=True)
        y = y.astype(float)
        return y
    return x


# apply transformation function
calc_num = ['temp', 't70', 'sbi5', 'sbi4', 'sbi2', 'sht5', 'sht4', 'sht2',
            'ati5', 'ati4', 'ati2', 'co2', 't60', 't2', 't6', 'wu2', 'wu5', 'wu10', 'pf550', 'pf950']
df_calc[calc_num] = df_calc[calc_num].transform(replace)

# drop unused columns
df_calc.drop(columns=['mykey', 'mylen', 'checksum',
             'testid', 'isindb'], inplace=True)

# filter data by ignore tag
df_chem = df_chem[df_chem['ignore'] == 'F']

# drop more unused columns
df_chem.drop(columns=['site_na', 'stamp', 'tempkey', 'serie', 'cal_des',
             'dpasse', 'fpasse', 'ignore', 'e_cd', 'da_id', 'e_cat'], inplace=True)

# define shared index
df_calc.set_index('nech', inplace=True)
df_chem.set_index('nech', inplace=True)

# join dataframes together
df = df_calc.join(df_chem, how='inner')

# merge dataframes with density data
df = pd.merge(df.reset_index(), df_dense.rename(
    columns={'N_lims': 'n_lims'}), on='e_cd', how='left')

# definable filters
f_keys = ['e_cd', 'site_na', 'produit', 'temp', 't60', 't70']
exc_list = ['fname', 'e_type', 'n_lims_x', 'n_lims_y', 'Nature',
            't2', 't6', 'wu2', 'wu5', 'wu10',
            'cao', 'co2', 'pf', 'pf550', 'pf700', 'pf950', 'pf1000',
            'lime', 'cao_m', 'sio2hum',
            'fe2o3li', 'na2oaa', 'k2oaa', 'sroaa', 'p2o5icp', 'pbxrf', 'fe2o3aa', 'mnoaa']

# drop columns baseed on exclusion list
df.drop(columns=exc_list, inplace=True)

# sort first columns
df = df[f_keys+[c for c in df if c not in f_keys]]
df = df.replace(0, np.nan)

# save df to csv
df.to_csv(os.path.join(os.path.dirname(os.getcwd()), META_PATH))

# drop rows based on dependent variable subset
df = df.dropna(axis=0, subset='t60')
#df = df.dropna(axis=0)

# filter by product type
df = df[df['produit'] == 'CALC']
df
# Out:
#        e_cd   site_na produit    temp    t60  t70    nech  sbi5  sbi4  sbi2  \
# 16    AGF 5  Araguaia    CALC   980.0   0.20  NaN  AGF005  2.76  0.73  0.42
# 17    AGF 5  Araguaia    CALC  1060.0   0.48  NaN  AGF005  2.72  0.51  0.29
# 18    AGF 5  Araguaia    CALC  1140.0   2.03  NaN  AGF005  3.26  0.80  0.38
# 19    AGF 5  Araguaia    CALC  1200.0   5.45  NaN  AGF005  4.00  0.58  0.31
# 20    AGF 6  Araguaia    CALC   980.0   0.23  NaN  AGF006  2.46  0.75  0.42
# ...     ...       ...     ...     ...    ...  ...     ...   ...   ...   ...
# 3323  WRK 7     Warak    CALC   900.0   8.42  NaN  WRK007  1.20  0.84  0.70
# 3324  WRK 7     Warak    CALC   980.0   9.50  NaN  WRK007  1.17  0.62  0.49
# 3325  WRK 7     Warak    CALC  1060.0  12.70  NaN  WRK007  1.15  0.68  0.54
# 3326  WRK 7     Warak    CALC  1140.0   9.30  NaN  WRK007  0.84  0.47  0.34
# 3327  WRK 7     Warak    CALC  1200.0   9.82  NaN  WRK007  0.48  0.24  0.21
#
#        sht5   sht4  sht2   ati5   ati4   ati2   mgo  sio2  fe2o3  al2o3  \
# 16     5.04   2.75  0.92   5.14   3.47   2.82  0.15  0.20   0.03   0.03
# 17     3.60   2.18  0.76   4.28   3.00   2.47  0.15  0.20   0.03   0.03
# 18     3.02   1.69  0.67   4.48   2.90   2.40  0.15  0.20   0.03   0.03
# 19     3.31   1.63  0.51   3.72   2.49   2.00  0.15  0.20   0.03   0.03
# 20     4.43   2.45  0.78   5.26   3.96   3.29  0.22  0.38   0.03   0.07
# ...     ...    ...   ...    ...    ...    ...   ...   ...    ...    ...
# 3323  16.15  12.37  8.73  37.26  32.16  30.87  0.41  0.14   0.02   0.02
# 3324  15.10  11.30  6.93  39.30  33.90  30.64  0.41  0.14   0.02   0.02
# 3325  15.63  11.69  6.72  45.91  39.94  34.30  0.41  0.14   0.02   0.02
# 3326  15.63  11.69  6.72  48.44  43.09  37.27  0.41  0.14   0.02   0.02
# 3327   5.22  11.80  6.88  47.55  42.59  37.60  0.41  0.14   0.02   0.02
#
#           s     mno    p2o5     sro    na2o     k2o      bao    tio2     va  \
# 16    0.002  0.0003  0.0246  0.4375  0.0021  0.0028  35.0000  0.0024   0.45
# 17    0.002  0.0003  0.0246  0.4375  0.0021  0.0028  35.0000  0.0024   0.45
# 18    0.002  0.0003  0.0246  0.4375  0.0021  0.0028  35.0000  0.0024   0.45
# 19    0.002  0.0003  0.0246  0.4375  0.0021  0.0028  35.0000  0.0024   0.45
# 20    0.006  0.0004  0.0336  0.4264  0.0021  0.0104  34.0000  0.0031   0.74
# ...     ...     ...     ...     ...     ...     ...      ...     ...    ...
# 3323  0.028  0.0013  0.0028  0.1050  0.1390  0.0103   0.0003  0.0016  12.00
# 3324  0.028  0.0013  0.0028  0.1050  0.1390  0.0103   0.0003  0.0016  12.00
# 3325  0.028  0.0013  0.0028  0.1050  0.1390  0.0103   0.0003  0.0016  12.00
# 3326  0.028  0.0013  0.0028  0.1050  0.1390  0.0103   0.0003  0.0016  12.00
# 3327  0.028  0.0013  0.0028  0.1050  0.1390  0.0103   0.0003  0.0016  12.00
#
#        zn  corg  Density  Porosity  WA24
# 16    1.0  0.05      NaN       NaN   NaN
# 17    1.0  0.05      NaN       NaN   NaN
# 18    1.0  0.05      NaN       NaN   NaN
# 19    1.0  0.05      NaN       NaN   NaN
# 20    1.2  0.08      NaN       NaN   NaN
# ...   ...   ...      ...       ...   ...
# 3323  1.8  0.09     2.51       7.2   NaN
# 3324  1.8  0.09     2.51       7.2   NaN
# 3325  1.8  0.09     2.51       7.2   NaN
# 3326  1.8  0.09     2.51       7.2   NaN
# 3327  1.8  0.09     2.51       7.2   NaN
#
# [2568 rows x 34 columns]

# %%
# show numer of samples per temperature
df['temp'].value_counts()
# Out:
# 1140.0    688
# 1060.0    624
# 980.0     591
# 1200.0    560
# 900.0      69
# 1100.0     23
# 1170.0      8
# 950.0       5
# Name: temp, dtype: int64

# %%
# set up machine learning model environment
s = setup(df[df['temp'] == 1140], target='t60', ignore_features=[
          'e_cd', 'produit', 't70', 'nech', 'temp'], train_size=0.8)
# Out:
# <style type="text/css">
# #T_893cb_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_893cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_893cb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_893cb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_893cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_893cb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_893cb_row0_col1" class="data row0 col1" >567</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_893cb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_893cb_row1_col1" class="data row1 col1" >t60</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_893cb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_893cb_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_893cb_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_893cb_row3_col1" class="data row3 col1" >(688, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_893cb_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_893cb_row4_col1" class="data row4 col1" >(550, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_893cb_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_893cb_row5_col1" class="data row5 col1" >(138, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_893cb_row6_col0" class="data row6 col0" >Ignore features</td>
#       <td id="T_893cb_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_893cb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_893cb_row7_col1" class="data row7 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_893cb_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_893cb_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_893cb_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_893cb_row9_col1" class="data row9 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_893cb_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_893cb_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_893cb_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_893cb_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_893cb_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_893cb_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_893cb_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_893cb_row13_col1" class="data row13 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_893cb_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_893cb_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_893cb_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_893cb_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_893cb_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_893cb_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_893cb_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_893cb_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_893cb_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_893cb_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_893cb_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_893cb_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_893cb_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_893cb_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_893cb_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_893cb_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_893cb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_893cb_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_893cb_row22_col1" class="data row22 col1" >61b7</td>
#     </tr>
#   </tbody>
# </table>

# %%
# compare regression models
best = compare_models(turbo=True)
# Out:
# <style type="text/css">
# #T_4954c th {
#   text-align: left;
# }
# #T_4954c_row0_col0, #T_4954c_row1_col0, #T_4954c_row1_col1, #T_4954c_row1_col2, #T_4954c_row1_col3, #T_4954c_row1_col4, #T_4954c_row1_col5, #T_4954c_row1_col6, #T_4954c_row2_col0, #T_4954c_row2_col1, #T_4954c_row2_col2, #T_4954c_row2_col3, #T_4954c_row2_col4, #T_4954c_row2_col5, #T_4954c_row2_col6, #T_4954c_row3_col0, #T_4954c_row3_col1, #T_4954c_row3_col2, #T_4954c_row3_col3, #T_4954c_row3_col4, #T_4954c_row3_col5, #T_4954c_row3_col6, #T_4954c_row4_col0, #T_4954c_row4_col1, #T_4954c_row4_col2, #T_4954c_row4_col3, #T_4954c_row4_col4, #T_4954c_row4_col5, #T_4954c_row4_col6, #T_4954c_row5_col0, #T_4954c_row5_col1, #T_4954c_row5_col2, #T_4954c_row5_col3, #T_4954c_row5_col4, #T_4954c_row5_col5, #T_4954c_row5_col6, #T_4954c_row6_col0, #T_4954c_row6_col1, #T_4954c_row6_col2, #T_4954c_row6_col3, #T_4954c_row6_col4, #T_4954c_row6_col5, #T_4954c_row6_col6, #T_4954c_row7_col0, #T_4954c_row7_col1, #T_4954c_row7_col2, #T_4954c_row7_col3, #T_4954c_row7_col4, #T_4954c_row7_col5, #T_4954c_row7_col6, #T_4954c_row8_col0, #T_4954c_row8_col1, #T_4954c_row8_col2, #T_4954c_row8_col3, #T_4954c_row8_col4, #T_4954c_row8_col5, #T_4954c_row8_col6, #T_4954c_row9_col0, #T_4954c_row9_col1, #T_4954c_row9_col2, #T_4954c_row9_col3, #T_4954c_row9_col4, #T_4954c_row9_col5, #T_4954c_row9_col6, #T_4954c_row10_col0, #T_4954c_row10_col1, #T_4954c_row10_col2, #T_4954c_row10_col3, #T_4954c_row10_col4, #T_4954c_row10_col5, #T_4954c_row10_col6, #T_4954c_row11_col0, #T_4954c_row11_col1, #T_4954c_row11_col2, #T_4954c_row11_col3, #T_4954c_row11_col4, #T_4954c_row11_col5, #T_4954c_row11_col6, #T_4954c_row12_col0, #T_4954c_row12_col1, #T_4954c_row12_col2, #T_4954c_row12_col3, #T_4954c_row12_col4, #T_4954c_row12_col5, #T_4954c_row12_col6, #T_4954c_row13_col0, #T_4954c_row13_col1, #T_4954c_row13_col2, #T_4954c_row13_col3, #T_4954c_row13_col4, #T_4954c_row13_col5, #T_4954c_row13_col6, #T_4954c_row14_col0, #T_4954c_row14_col1, #T_4954c_row14_col2, #T_4954c_row14_col3, #T_4954c_row14_col4, #T_4954c_row14_col5, #T_4954c_row14_col6, #T_4954c_row15_col0, #T_4954c_row15_col1, #T_4954c_row15_col2, #T_4954c_row15_col3, #T_4954c_row15_col4, #T_4954c_row15_col5, #T_4954c_row15_col6, #T_4954c_row16_col0, #T_4954c_row16_col1, #T_4954c_row16_col2, #T_4954c_row16_col3, #T_4954c_row16_col4, #T_4954c_row16_col5, #T_4954c_row16_col6, #T_4954c_row17_col0, #T_4954c_row17_col1, #T_4954c_row17_col2, #T_4954c_row17_col3, #T_4954c_row17_col4, #T_4954c_row17_col5, #T_4954c_row17_col6, #T_4954c_row18_col0, #T_4954c_row18_col1, #T_4954c_row18_col2, #T_4954c_row18_col3, #T_4954c_row18_col4, #T_4954c_row18_col5, #T_4954c_row18_col6, #T_4954c_row19_col0, #T_4954c_row19_col1, #T_4954c_row19_col2, #T_4954c_row19_col3, #T_4954c_row19_col4, #T_4954c_row19_col5, #T_4954c_row19_col6 {
#   text-align: left;
# }
# #T_4954c_row0_col1, #T_4954c_row0_col2, #T_4954c_row0_col3, #T_4954c_row0_col4, #T_4954c_row0_col5, #T_4954c_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4954c_row0_col7, #T_4954c_row1_col7, #T_4954c_row2_col7, #T_4954c_row3_col7, #T_4954c_row4_col7, #T_4954c_row5_col7, #T_4954c_row6_col7, #T_4954c_row7_col7, #T_4954c_row8_col7, #T_4954c_row9_col7, #T_4954c_row10_col7, #T_4954c_row11_col7, #T_4954c_row13_col7, #T_4954c_row14_col7, #T_4954c_row15_col7, #T_4954c_row16_col7, #T_4954c_row17_col7, #T_4954c_row18_col7, #T_4954c_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4954c_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4954c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4954c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4954c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4954c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4954c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4954c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4954c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4954c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4954c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4954c_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_4954c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_4954c_row0_col1" class="data row0 col1" >3.4101</td>
#       <td id="T_4954c_row0_col2" class="data row0 col2" >34.5042</td>
#       <td id="T_4954c_row0_col3" class="data row0 col3" >5.6165</td>
#       <td id="T_4954c_row0_col4" class="data row0 col4" >0.4434</td>
#       <td id="T_4954c_row0_col5" class="data row0 col5" >0.5154</td>
#       <td id="T_4954c_row0_col6" class="data row0 col6" >0.7387</td>
#       <td id="T_4954c_row0_col7" class="data row0 col7" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_4954c_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_4954c_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_4954c_row1_col1" class="data row1 col1" >3.4466</td>
#       <td id="T_4954c_row1_col2" class="data row1 col2" >34.5569</td>
#       <td id="T_4954c_row1_col3" class="data row1 col3" >5.6329</td>
#       <td id="T_4954c_row1_col4" class="data row1 col4" >0.4400</td>
#       <td id="T_4954c_row1_col5" class="data row1 col5" >0.5257</td>
#       <td id="T_4954c_row1_col6" class="data row1 col6" >0.7489</td>
#       <td id="T_4954c_row1_col7" class="data row1 col7" >0.9410</td>
#     </tr>
#     <tr>
#       <th id="T_4954c_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_4954c_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_4954c_row2_col1" class="data row2 col1" >3.6157</td>
#       <td id="T_4954c_row2_col2" class="data row2 col2" >36.9488</td>
#       <td id="T_4954c_row2_col3" class="data row2 col3" >5.8445</td>
#       <td id="T_4954c_row2_col4" class="data row2 col4" >0.3928</td>
#       <td id="T_4954c_row2_col5" class="data row2 col5" >0.5621</td>
#       <td id="T_4954c_row2_col6" class="data row2 col6" >0.8906</td>
#       <td id="T_4954c_row2_col7" class="data row2 col7" >0.1200</td>
#     </tr>
#     <tr>
#       <th id="T_4954c_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_4954c_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_4954c_row3_col1" class="data row3 col1" >3.7408</td>
#       <td id="T_4954c_row3_col2" class="data row3 col2" >38.6837</td>
#       <td id="T_4954c_row3_col3" class="data row3 col3" >5.9884</td>
#       <td id="T_4954c_row3_col4" class="data row3 col4" >0.3669</td>
#       <td id="T_4954c_row3_col5" class="data row3 col5" >0.5599</td>
#       <td id="T_4954c_row3_col6" class="data row3 col6" >0.8615</td>
#       <td id="T_4954c_row3_col7" class="data row3 col7" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_4954c_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_4954c_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4954c_row4_col1" class="data row4 col1" >3.7389</td>
#       <td id="T_4954c_row4_col2" class="data row4 col2" >38.9956</td>
#       <td id="T_4954c_row4_col3" class="data row4 col3" >6.0012</td>
#       <td id="T_4954c_row4_col4" class="data row4 col4" >0.3641</td>
#       <td id="T_4954c_row4_col5" class="data row4 col5" >0.5736</td>
#       <td id="T_4954c_row4_col6" class="data row4 col6" >0.8087</td>
#       <td id="T_4954c_row4_col7" class="data row4 col7" >0.2740</td>
#     </tr>
#     <tr>
#       <th id="T_4954c_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_4954c_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_4954c_row5_col1" class="data row5 col1" >3.6619</td>
#       <td id="T_4954c_row5_col2" class="data row5 col2" >39.0322</td>
#       <td id="T_4954c_row5_col3" class="

# %%
# show statistics for model with best R2
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
